# %%
#期货多品种60分钟日ATR0.02波动系统（下一个交易日开盘买入实现）
import datetime  # For datetime objects

import sys  # To find out the script name (in argv[0])
import pandas as pd
import time as tm
import matplotlib.pyplot as plt
import backtrader.analyzers as btanalyzers
import math
import numpy as np
import quantstats

# Import the backtrader platform
import backtrader as bt
import akshare as ak
import os
os.environ['DISPLAY'] = ':2'
#%matplotlib auto
import telegram
TOKEN = '*******************8'
bot = telegram.Bot(TOKEN)
import autotrade

from jqdatasdk import *
auth('13********','********') 
count=get_query_count()
print(count)

def read_csv(code,time,date):
    code =normalize_code(code)
    data = pd.read_csv("/code/data/" + time  +"/" + code)
    data['date'] = pd.to_datetime(data['date'])
    data.set_index("date",inplace=True)
    return data.loc[date:]
    
def get_data(code,time):
            data= ak.futures_zh_minute_sina(symbol=code, period=time)
            data['date'] = pd.to_datetime(data['date'])
            data.set_index("date",inplace=True)
            data.drop(columns=['hold'],inplace = True)
            data=data.astype({
                    'open': 'float',
                    'high':'float',
                    'low':'float',
                    'close':'float',
                    'volume':'float'
                })
            tm.sleep(1)
            return data 
def Tg_send(time,code,signal,close,size):
            now=datetime.datetime.now()
            now_str=now.strftime('%Y-%m-%d')
            #now_str = "2021-02-02"
            if time == now_str:
                sizes = autotrade._size(code,size) #计算实盘用的交易手数
                f = open('/code/log.txt', 'r').read()
                x = "%s,code=%s,%s" % (time,code,signal)
                if x in f :
                    print("当天已经执行过了")
                else:
                    print("发出信号，正在执行实盘...")
                    position=100;close_position = 100
                    if signal == "做多":
                        position = autotrade.buy_open(code[:-4],sizes)    #如果返回1说明软件中有仓位。
                        print(code[:-4])
                        print(position)
                        tm.sleep(2)
                    if signal == "做空":
                        position = autotrade.sell_open(code[:-4],sizes) #如果返回1说明软件中有仓位
                        tm.sleep(2)
                    if signal == "平多":                                  
                        close_position = autotrade.sell_close(code[:-4],sizes)   #如果返回0说明软件中无仓位。
                        tm.sleep(2)
                    if signal == "平空":
                        close_position = autotrade.buy_close(code[:-4],sizes)   #如果返回0说明软件中无仓位。
                        tm.sleep(2)
                    if position == 1 or close_position ==0:   #如果执行命令成功
                        print("实盘执行成功，当前时间发出%s信号,正在推送TG..."% (signal))
                        bot.send_message(chat_id='727256696', text="品种:%s ,价格:%.2f ,发出%s信号！" % (code,close,signal))
                        os.system('echo %s,code=%s,%s >>/code/log.txt' % (time,code,signal) )
class TestStrategy(bt.Strategy):
    def log(self, txt, dt=None):
        ''' Logging function fot this strategy'''
        dt = dt or self.datas[0].datetime.date(0)
        print('{}, {}'.format(dt.isoformat(), txt))
        
        
    def __init__(self):
        self.signal = {}
        # 保存现有持仓的股票
        self.position_dict={}

        self.inds = dict()
        for d in self.datas[1:]:
            
            self.inds[d] = dict()
            # Add a MovingAverageSimple indicator
            # 50日移动平均线
            self.inds[d]['sma50'] = bt.indicators.SimpleMovingAverage(d.close,period=50)
            # 100日移动平均线
            self.inds[d]['sma100'] = bt.indicators.SimpleMovingAverage(d.close,period=100)
            # 100 日真实波动ATR
            self.inds[d]['atr100'] = bt.indicators.AverageTrueRange(d, period=100)
            # 50日的收盘最高价
            self.inds[d]['High50'] = bt.indicators.Highest(d.close(-1), period=50,subplot=False)
            # 50日的收盘最低价
            self.inds[d]['Low50'] = bt.indicators.Lowest(d.close(-1), period=50,subplot=False)
 
    def prenext(self):
        #print("prenext")
        self.next()

    def next(self):
        index_date = self.datas[0].datetime.date(0).strftime('%Y-%m-%d')  #指数index当前交易日
        for d in self.datas[1:]:
            dt_str = d.datetime.date(0).strftime('%Y-%m-%d')
            pos = self.getposition(d).size
            getcash = self.broker.getvalue()
            #print(pos)
            if  pos ==0:  # no market / no orders
                if self.inds[d]['sma50'][0] > self.inds[d]['sma100'][0] and d.close[0] > self.inds[d]['High50'][0]:
                        if index_date != dt_str:     #如果指数index日期等于品种日期说明正在交易当中
                            #print("指数日期和品种日期不相等")
                            continue
                        if d._name in self.position_dict:
                            #print("已经有做多的订单了")
                            continue
                        size =(0.002*getcash)/(self.inds[d]['atr100'][0]*10)
                        if math.isnan(size):  #判断size是否为nan
                            size = (getcash/len(self.datas))/(d.close[0]*10)   #如果ATR计算失败就进行等额计算总资金/品种数目/价格
                        cerebro.broker.setcommission(commission=1.0,margin=int(d.close[0]),mult=10,name=d._name)
                        self.order = self.buy(data=d,size = size)
                        self.position_dict[d._name] = self.order
                        self.log('做多品种:' + d._name + ',做多价格： %.2f' % d.close[0])
                        self.signal[d._name] = [dt_str,"做多",size]

                if self.inds[d]['sma50'][0]  < self.inds[d]['sma100'][0] and d.close[0] < self.inds[d]['Low50'][0]:
                    if index_date != dt_str:     #如果指数index日期等于品种日期说明正在交易当中
                            #print("指数日期和品种日期不相等")
                            continue
                    if d._name in self.position_dict:
                            #print("已经有做空的订单了")
                            continue
                    size=(0.002*getcash)/(self.inds[d]['atr100'][0]*10)
                    if math.isnan(size):  #判断size是否为nan
                            print("Nan")
                            size = (getcash/len(self.datas))/(d.close[0]*10)   #如果ATR计算失败就进行等额计算总资金/品种数目/价格
                    cerebro.broker.setcommission(commission=1.0,margin=int(d.close[0]),mult=10,name=d._name)
                    self.order = self.sell(data=d,size = size)
                    self.position_dict[d._name] = self.order                  
                    self.log('做空品种:' + d._name + ',做空价格： %.2f' % d.close[0])
                    self.signal[d._name] = [dt_str,"做空",size]
            else :
                if self.getposition(d).size > 0  and d.close[0] < self.inds[d]['High50'][0] - 3*self.inds[d]['atr100'][0]:
                        if d._name in self.position_dict:
                            self.order = self.close(data=d)
                            #print(self.getposition(d).size)
                            self.log('平多品种:' + d._name + ',平多价格： %.2f' % d.close[0])
                            self.position_dict.pop(d._name)
                            self.signal[d._name] = [dt_str,"平多",self.getposition(d).size]

                
                if self.getposition(d).size < 0 and d.close[0] > self.inds[d]['Low50'][0] + 3*self.inds[d]['atr100'][0]:
                        if d._name in self.position_dict:
                            self.order = self.close(data=d)
                            self.log('平空品种:' + d._name + ',平空价格： %.2f' % d.close[0])
                            self.position_dict.pop(d._name)
                            self.signal[d._name] = [dt_str,"平空",self.getposition(d).size*-1]


    def notify_order(self, order):
        
        if order.status in [order.Submitted, order.Accepted]:
            return
        
        if order.status == order.Rejected:
            self.log(f"Rejected : order_ref:{order.ref}  data_name:{order.p.data._name}")
            
        if order.status == order.Margin:
            self.log(f"Margin : order_ref:{order.ref}  data_name:{order.p.data._name}")
            
        if order.status == order.Cancelled:
            self.log(f"Concelled : order_ref:{order.ref}  data_name:{order.p.data._name}")
            
        if order.status == order.Partial:
            self.log(f"Partial : order_ref:{order.ref}  data_name:{order.p.data._name}")
         
        if order.status == order.Completed:
            index_date = self.datas[0].datetime.date(0).strftime('%Y-%m-%d') 
            if order.isbuy():
                self.log(f" BUY : data_name:{order.p.data._name} price : {order.executed.price} , cost : {order.executed.value} , commission : {order.executed.comm}")                
                dt_str,signal,size = self.signal[order.p.data._name]
                Tg_send(time=index_date, code = order.p.data._name, signal = signal, close = order.executed.price, size=size)
                
            else:  # Sell
                self.log(f" SELL : data_name:{order.p.data._name} price : {order.executed.price} , cost : {order.executed.value} , commission : {order.executed.comm}")
                dt_str,signal,size = self.signal[order.p.data._name]
                Tg_send(time=index_date, code = order.p.data._name, signal = signal, close = order.executed.price, size=size)
                
    def notify_trade(self, trade):
        # 一个trade结束的时候输出信息
        if trade.isclosed:
            self.log('closed symbol is : {} , total_profit : {} , net_profit : {}' .format(
                            trade.getdataname(),trade.pnl, trade.pnlcomm))
            # self.trade_list.append([self.datas[0].datetime.date(0),trade.getdataname(),trade.pnl,trade.pnlcomm])
            
        if trade.isopen:
            self.log('open symbol is : {} , price : {} ' .format(
                            trade.getdataname(),trade.price))

    def stop(self):
        self.log('结束')


if __name__ == '__main__':

    # 初始化模型
    cerebro = bt.Cerebro()
    # 构建策略
    strats = cerebro.addstrategy(TestStrategy)
    #品种池
    code_range =['AL8888','JD8888','BU8888','UR8888','C8888','M8888','RM8888','TA8888','MA8888','FG8888','PF8888','SA8888','FU8888',
                 'CU8888','ZN8888','RB8888','RU8888','HC8888','SS8888','P8888','J8888','Y8888','JM8888','I8888','AP8888','CJ8888',
                 'SR8888','CF8888']
    #code_range =['AL8888','JD8888','BU8888','UR8888','SA8888','CU8888']
    #code_range =['TA8888','MA8888','C8888','M8888','FG8888','RB8888']
    #code_range =['BU8888']
    #start_date = datetime.datetime(2018,1,1)  # 回测开始时间
    #end_date = datetime.datetime(2021,4,30)  # 回测结束时间   
    dataname = read_csv('AL8888','60m','2021-03-01 10:00:00') 
    print(dataname)
    data = bt.feeds.PandasData(dataname=dataname,timeframe=bt.TimeFrame.Minutes,compression=60)  # 加载指数数据
    cerebro.adddata(data,name = 'index')  # 指数数据
    for code_name in code_range:
        #dataname = get_data(code_name,"60")
        dataname = read_csv(code_name,'60m','2021-03-01 10:00:00')  #'1m', '5m', '15m', '30m', '60m', '120m', '1d', '1w'(一周), '1M'（一月）
        print(code_name)
        print(dataname)
        data = bt.feeds.PandasData(dataname=dataname,timeframe=bt.TimeFrame.Minutes,compression=60)  # 加载数据
        cerebro.adddata(data,name = code_name)  # 将数据传入回测系统
    
    print("加载数据完毕")
    # 设定初始资金和佣金
    cerebro.broker.setcash(8500000.0)
    #cerebro.broker.setcommission(0.0002)
    #cerebro.addsizer(bt.sizers.PercentSizer, percents=12)

    # 以发出信号当日收盘价成交
    #cerebro.broker.set_coc(True)
    # 策略执行前的资金
    print('启动资金: %.2f' % cerebro.broker.getvalue())

    # 策略执行
    #cerebro.run()
    print('结束资金: %.2f' % cerebro.broker.getvalue())
    

    cerebro.addanalyzer(btanalyzers.SharpeRatio, _name = 'sharpe')
    cerebro.addanalyzer(btanalyzers.DrawDown, _name = 'drawdown')
    cerebro.addanalyzer(btanalyzers.Returns, _name='returns')
    cerebro.addanalyzer(btanalyzers.TradeAnalyzer, _name='track')
    cerebro.addanalyzer(bt.analyzers.PyFolio, _name='PyFolio')



    cerebro.broker.set_fundstartval(1)
    print(f'Starte Portfolio Value {cerebro.broker.getvalue()}')
    result = cerebro.run()
    print('----------------------------')
    print(f'End portfolio value {cerebro.broker.getvalue()}')
    print(cerebro.broker.get_fundvalue())
    print('----------------------------')
    print(f"Total Return:  {round(result[0].analyzers.returns.get_analysis()['rtot']*100, 2)}%")
    print(f"APR:           {round(result[0].analyzers.returns.get_analysis()['rnorm100'],2)}%")
    print(f"Max DrawDown:  {round(result[0].analyzers.drawdown.get_analysis()['max']['drawdown'],2)}%")
    trade = result[0].analyzers.track.get_analysis()
    print("总交易次数 =%s,还在交易=%s,完成的交易=%s.交易成功率百分比=%.2f ,盈亏百分比=%.2f" % 
          (str(trade['total']['total']),str(trade['total']['open']),str(trade['total']['closed']),
           trade['won']['total']/trade['total']['closed']*100,trade['won']['pnl']['average']/abs(trade['lost']['pnl']['average'])))
    
    print("连续盈利次数 = %s, 连续亏损次数= %s" % (str(trade['streak']['won']['longest']),str(trade['streak']['lost']['longest'])))
    print("总盈利次数 = %i , 总盈利 = %.2f , 平均盈利 =%.2f ,单次最大盈利 = %.2f " 
           %  (trade['won']['total'],trade['won']['pnl']['total'],trade['won']['pnl']['average'],trade['won']['pnl']['max']))
    print("总亏损次数 = %i, 总亏损 = %.2f, 平均亏损 =%.2f,单次最大亏损 = %.2f" 
           %  (trade['lost']['total'],trade['lost']['pnl']['total'],trade['lost']['pnl']['average'],trade['lost']['pnl']['max']))
    portfolio_stats = result[0].analyzers.getbyname('PyFolio')
    returns, positions, transactions, gross_lev = portfolio_stats.get_pf_items()
    returns.index = returns.index.tz_convert(None)
    transactions.index = transactions.index.tz_convert(None)
    quantstats.reports.html(returns,output=f'/data/muma/index666.html', title=f' 期货多品种交易系统60m ATR0.001 Analysis')
  
    #cerebro.plot(iplot=True,style = "bar",barup = "red",bardown ="green")  # 绘图
# Out:
# 提示：当前环境 pandas 版本高于 0.25，get_price 与 get_fundamentals_continuously 接口 panel 参数将固定为 False
# 注意：0.25 以上版本 pandas 不支持 panel，如使用该数据结构和相关函数请注意修改
# auth success
# {'total': 1000000, 'spare': 995977}
#                           open       high        low      close
# date
# 2021-03-01 10:00:00  17034.928  17157.520  16940.001  17114.781
# 2021-03-01 11:00:00  17117.413  17133.415  16975.037  16994.344
# 2021-03-01 11:30:00  16995.193  17026.677  16916.399  16983.996
# 2021-03-01 14:00:00  16966.508  16990.158  16824.065  16839.219
# 2021-03-01 15:00:00  16839.273  17028.168  16794.832  16961.114
# ...                        ...        ...        ...        ...
# 2021-05-12 11:00:00  19859.998  20025.790  19855.352  19971.681
# 2021-05-12 11:30:00  19971.821  20009.738  19930.500  19969.651
# 2021-05-12 14:00:00  19979.259  20038.961  19933.176  19978.967
# 2021-05-12 15:00:00  19979.185  20006.407  19943.951  19965.758
# 2021-05-12 21:01:00  19662.282  19693.743  19542.546  19545.402
#
# [428 rows x 4 columns]
# AL8888
#                           open       high        low      close
# date
# 2021-03-01 10:00:00  17034.928  17157.520  16940.001  17114.781
# 2021-03-01 11:00:00  17117.413  17133.415  16975.037  16994.344
# 2021-03-01 11:30:00  16995.193  17026.677  16916.399  16983.996
# 2021-03-01 14:00:00  16966.508  16990.158  16824.065  16839.219
# 2021-03-01 15:00:00  16839.273  17028.168  16794.832  16961.114
# ...                        ...        ...        ...        ...
# 2021-05-12 11:00:00  19859.998  20025.790  19855.352  19971.681
# 2021-05-12 11:30:00  19971.821  20009.738  19930.500  19969.651
# 2021-05-12 14:00:00  19979.259  20038.961  19933.176  19978.967
# 2021-05-12 15:00:00  19979.185  20006.407  19943.951  19965.758
# 2021-05-12 21:01:00  19662.282  19693.743  19542.546  19545.402
#
# [428 rows x 4 columns]
# JD8888
#                          open      high       low     close
# date
# 2021-03-01 10:00:00  4681.298  4681.604  4576.827  4584.911
# 2021-03-01 11:00:00  4583.877  4584.339  4547.423  4561.095
# 2021-03-01 11:30:00  4560.409  4560.647  4525.613  4525.613
# 2021-03-01 14:00:00  4523.658  4561.237  4514.245  4553.677
# 2021-03-01 15:00:00  4551.785  4568.136  4524.077  4525.317
# ...                       ...       ...       ...       ...
# 2021-05-12 10:00:00  4687.126  4718.253  4681.084  4704.870
# 2021-05-12 11:00:00  4704.853  4705.783  4693.967  4701.503
# 2021-05-12 11:30:00  4700.974  4717.155  4696.277  4698.271
# 2021-05-12 14:00:00  4696.302  4696.302  4675.999  4677.724
# 2021-05-12 15:00:00  4677.659  4698.410  4676.416  4693.412
#
# [245 rows x 4 columns]
# BU8888
#                          open      high       low     close
# date
# 2021-03-01 10:00:00  3248.652  3279.602  3224.680  3248.763
# 2021-03-01 11:00:00  3250.378  3254.027  3208.885  3214.448
# 2021-03-01 11:30:00  3212.583  3214.509  3181.034  3184.926
# 2021-03-01 14:00:00  3186.468  3199.663  3142.315  3150.235
# 2021-03-01 15:00:00  3151.644  3161.682  3132.063  3158.791
# ...                       ...       ...       ...       ...
# 2021-05-12 11:00:00  3098.407  3123.679  3098.183  3108.463
# 2021-05-12 11:30:00  3109.769  3127.904  3105.423  3122.504
# 2021-05-12 14:00:00  3127.067  3150.413  3124.856  3143.166
# 2021-05-12 15:00:00  3144.676  3167.683  3133.420  3167.216
# 2021-05-12 21:01:00  3172.521  3179.114  3155.018  3157.932
#
# [338 rows x 4 columns]
# UR8888
#                          open      high       low     close
# date
# 2021-03-01 10:00:00  1953.765  1964.198  1904.610  1928.800
# 2021-03-01 11:00:00  1928.650  1932.520  1913.664  1915.485
# 2021-03-01 11:30:00  1915.335  1923.808  1912.528  1919.236
# 2021-03-01 14:00:00  1919.090  1927.050  1914.163  1925.511
# 2021-03-01 15:00:00  1925.437  1934.234  1910.528  1931.278
# ...                       ...       ...       ...       ...
# 2021-05-12 10:00:00  2204.181  2252.554  2201.033  2240.089
# 2021-05-12 11:00:00  2239.374  2240.089  2215.219  2233.041
# 2021-05-12 11:30:00  2232.807  2235.471  2224.004  2228.105
# 2021-05-12 14:00:00  2228.100  2246.306  2228.100  2243.372
# 2021-05-12 15:00:00  2242.656  2252.675  2237.430  2244.807
#
# [245 rows x 4 columns]
# C8888
#                          open      high       low     close
# date
# 2021-03-01 10:00:00  2783.644  2794.737  2763.314  2772.133
# 2021-03-01 11:00:00  2770.945  2775.162  2761.774  2763.198
# 2021-03-01 11:30:00  2763.420  2768.621  2760.646  2765.845
# 2021-03-01 14:00:00  2765.947  2780.030  2765.560  2778.453
# 2021-03-01 15:00:00  2777.859  2781.897  2770.155  2772.374
# ...                       ...       ...       ...       ...
# 2021-05-12 11:00:00  2843.284  2866.739  2843.115  2863.132
# 2021-05-12 11:30:00  2863.031  2871.538  2861.986  2865.375
# 2021-05-12 14:00:00  2864.675  2875.820  2864.675  2871.904
# 2021-05-12 15:00:00  2871.904  2872.007  2851.508  2861.242
# 2021-05-12 21:01:00  2858.852  2859.552  2842.698  2847.449
#
# [338 rows x 4 columns]
# M8888
#                          open      high       low     close
# date
# 2021-03-01 10:00:00  3461.017  3477.471  3448.376  3459.835
# 2021-03-01 11:00:00  3459.000  3465.326  3450.892  3458.095
# 2021-03-01 11:30:00  3458.436  3458.967  3436.210  3439.199
# 2021-03-01 14:00:00  3439.875  3445.786  3434.758  3441.700
# 2021-03-01 15:00:00  3440.690  3453.054  3435.376  3436.757
# ...                       ...       ...       ...       ...
# 2021-05-12 11:00:00  3740.164  3748.633  3733.171  3740.711
# 2021-05-12 11:30:00  3740.969  3752.365  3736.867  3739.749
# 2021-05-12 14:00:00  3741.565  3758.422  3739.276  3756.658
# 2021-05-12 15:00:00  3756.441  3761.270  3742.319  3742.964
# 2021-05-12 21:01:00  3737.276  3737.300  3717.328  3718.102
#
# [338 rows x 4 columns]
# RM8888
#                          open      high       low     close
# date
# 2021-03-01 10:00:00  2869.970  2904.851  2868.754  2884.079
# 2021-03-01 11:00:00  2883.373  2895.093  2876.153  2883.524
# 2021-03-01 11:30:00  2882.550  2886.517  2870.350  2872.888
# 2021-03-01 14:00:00  2873.534  2882.249  2863.181  2871.267
# 2021-03-01 15:00:00  2871.201  2887.895  2862.958  2865.350
# ...                       ...       ...       ...       ...
# 2021-05-12 11:00:00  3129.520  3142.434  3125.221  3137.255
# 2021-05-12 11:30:00  3137.379  3153.729  3137.315  3144.189
# 2021-05-12 14:00:00  3144.539  3154.534  3141.128  3154.469
# 2021-05-12 15:00:00  3153.548  3169.264  3144.358  3147.840
# 2021-05-12 21:01:00  3139.523  3139.853  3128.029  3130.777
#
# [338 rows x 4 columns]
# TA8888
#                          open      high       low     close
# date
# 2021-03-01 10:00:00  4911.817  4962.609  4843.274  4872.997
# 2021-03-01 11:00:00  4873.021  4882.048  4819.505  4825.328
# 2021-03-01 11:30:00  4823.103  4844.280  4779.330  4816.094
# 2021-03-01 14:00:00  4816.597  4835.313  4772.664  4803.871
# 2021-03-01 15:00:00  4803.826  4817.841  4783.606  4797.553
# ...                       ...       ...       ...       ...
# 2021-05-12 11:00:00  4824.801  4859.598  4816.317  4837.589
# 2021-05-12 11:30:00  4837.116  4861.653  4822.899  4844.999
# 2021-05-12 14:00:00  4851.559  4894.141  4850.926  4867.973
# 2021-05-12 15:00:00  4868.031  4906.224  4843.506  4901.205
# 2021-05-12 21:01:00  4900.005  4902.201  4884.375  4887.506
#
# [338 rows x 4 columns]
# MA8888
#                          open      high       low     close
# date
# 2021-03-01 10:00:00  2577.655  2579.755  2538.954  2552.386
# 2021-03-01 11:00:00  2552.766  2558.048  2528.414  2537.199
# 2021-03-01 11:30:00  2538.051  2539.120  2513.286  2528.819
# 2021-03-01 14:00:00  2530.344  2530.630  2492.164  2508.278
# 2021-03-01 15:00:00  2508.216  2527.430  2497.801  2526.211
# ...                       ...       ...       ...       ...
# 2021-05-12 11:00:00  2613.468  2698.118  2609.186  2694.497
# 2021-05-12 11:30:00  2694.457  2713.213  2692.581  2713.073
# 2021-05-12 14:00:00  2713.311  2714.695  2713.108  2713.745
# 2021-05-12 15:00:00  2713.742  2714.669  2713.148  2714.669
# 2021-05-12 21:01:00  2733.017  2737.115  2722.661  2724.033
#
# [338 rows x 4 columns]
# FG8888
#                          open      high       low     close
# date
# 2021-03-01 10:00:00  2086.780  2096.464  2069.851  2076.884
# 2021-03-01 11:00:00  2076.915  2079.834  2059.114  2064.444
# 2021-03-01 11:30:00  2064.413  2064.413  2044.300  2059.698
# 2021-03-01 14:00:00  2060.076  2061.426  2045.622  2057.600
# 2021-03-01 15:00:00  2055.971  2077.883  2054.284  2058.441
# ...                       ...       ...       ...       ...
# 2021-05-12 11:00:00  2803.266  2809.937  2790.816  2802.525
# 2021-05-12 11:30:00  2802.068  2804.666  2787.926  2793.155
# 2021-05-12 14:00:00  2794.192  2831.889  2793.167  2823.772
# 2021-05-12 15:00:00  2841.173  2880.762  2830.497  2877.101
# 2021-05-12 21:01:00  2846.486  2856.360  2841.014  2841.199
#
# [338 rows x 4 columns]
# PF8888
#                          open      high       low     close
# date
# 2021-03-01 10:00:00  8240.471  8370.340  8134.038  8169.051
# 2021-03-01 11:00:00  8167.092  8189.644  7997.113  8015.958
# 2021-03-01 11:30:00  8013.998  8034.717  7921.780  7966.314
# 2021-03-01 14:00:00  7966.792  8013.010  7917.025  7958.528
# 2021-03-01 15:00:00  7958.687  8038.739  7930.791  8029.047
# ...                       ...       ...       ...       ...
# 2021-05-12 11:00:00  7261.721  7297.673  7258.385  7295.533
# 2021-05-12 11:30:00  7296.613  7333.551  7288.202  7312.423
# 2021-05-12 14:00:00  7316.512  7363.309  7315.760  7338.643
# 2021-05-12 15:00:00  7338.792  7375.357  7326.387  7372.772
# 2021-05-12 21:01:00  7366.861  7384.785  7346.741  7354.075
#
# [338 rows x 4 columns]
# SA8888
#                          open      high       low     close
# date
# 2021-03-01 10:00:00  1928.220  1943.323  1900.274  1932.408
# 2021-03-01 11:00:00  1933.306  1936.134  1916.993  1923.507
# 2021-03-01 11:30:00  1924.298  1925.218  1903.727  1910.426
# 2021-03-01 14:00:00  1910.422  1918.112  1898.575  1917.347
# 2021-03-01 15:00:00  1917.398  1951.158  1914.077  1926.882
# ...                       ...       ...       ...       ...
# 2021-05-12 11:00:00  2167.331  2190.954  2163.668  2190.676
# 2021-05-12 11:30:00  2190.710  2231.945  2181.975  2214.719
# 2021-05-12 14:00:00  2216.064  2264.923  2215.430  2264.113
# 2021-05-12 15:00:00  2264.332  2278.857  2239.571  2250.289
# 2021-05-12 21:01:00  2237.657  2245.422  2233.658  2237.010
#
# [338 rows x 4 columns]
# FU8888
#                          open      high       low     close
# date
# 2021-03-01 10:00:00  2441.258  2488.855  2440.017  2467.666
# 2021-03-01 11:00:00  2468.007  2473.222  2453.804  2456.405
# 2021-03-01 11:30:00  2456.384  2459.052  2442.634  2451.518
# 2021-03-01 14:00:00  2450.521  2457.888  2424.945  2434.205
# 2021-03-01 15:00:00  2434.198  2434.198  2422.599  2429.808
# ...                       ...       ...       ...       ...
# 2021-05-12 11:00:00  2519.839  2527.555  2517.016  2519.020
# 2021-05-12 11:30:00  2518.017  2527.870  2516.134  2522.884
# 2021-05-12 14:00:00  2528.756  2547.516  2527.863  2541.759
# 2021-05-12 15:00:00  2542.649  2559.803  2533.797  2559.590
# 2021-05-12 21:01:00  2565.827  2565.837  2554.615  2554.729
#
# [338 rows x 4 columns]
# CU8888
#                           open       high        low      close
# date
# 2021-03-01 10:00:00  67476.515  68091.809  67469.862  67810.338
# 2021-03-01 11:00:00  67804.895  67898.552  67414.299  67528.226
# 2021-03-01 11:30:00  67532.553  67557.215  67236.752  67318.048
# 2021-03-01 14:00:00  67374.430  67589.060  67226.809  67291.422
# 2021-03-01 15:00:00  67286.298  67659.255  67174.552  67473.083
# ...                        ...        ...        ...        ...
# 2021-05-12 11:00:00  76482.682  76769.103  76444.731  76685.565
# 2021-05-12 11:30:00  76678.330  77027.100  76623.025  76824.577
# 2021-05-12 14:00:00  76945.586  77337.691  76907.206  76989.219
# 2021-05-12 15:00:00  76980.929  77321.979  76821.172  77283.685
# 2021-05-12 21:01:00  76474.139  76563.916  75677.919  75685.932
#
# [428 rows x 4 columns]
# ZN8888
#                           open       high        low      close
# date
# 2021-03-01 10:00:00  21161.981  21346.877  21137.242  21308.560
# 2021-03-01 11:00:00  21314.078  21374.398  21305.072  21332.285
# 2021-03-01 11:30:00  21334.249  21396.489  21281.092  21340.422
# 2021-03-01 14:00:00  21343.452  21385.438  21286.952  21347.919
# 2021-03-01 15:00:00  21346.496  21429.555  21290.535  21317.411
# ...                        ...        ...        ...        ...
# 2021-05-12 11:00:00  22400.460  22465.968  22395.744  22450.253
# 2021-05-12 11:30:00  22452.283  22501.400  22427.600  22445.136
# 2021-05-12 14:00:00  22487.271  22544.305  22457.017  22492.688
# 2021-05-12 15:00:00  22489.313  22537.261  22448.830  22530.104
# 2021-05-12 21:01:00  22337.233  22363.660  22159.768  22197.232
#
# [428 rows x 4 columns]
# RB8888
#                          open      high       low     close
# date
# 2021-03-01 10:00:00  4655.045  4682.574  4620.415  4655.035
# 2021-03-01 11:00:00  4654.513  4661.408  4604.944  4612.422
# 2021-03-01 11:30:00  4612.934  4620.072  4593.711  4596.785
# 2021-03-01 14:00:00  4600.715  4610.651  4585.736  4609.294
# 2021-03-01 15:00:00  4609.279  4643.087  4601.984  4621.254
# ...                       ...       ...       ...       ...
# 2021-05-12 11:00:00  6058.278  6108.560  6054.797  6092.719
# 2021-05-12 11:30:00  6091.870  6131.667  6074.460  6083.432
# 2021-05-12 14:00:00  6091.412  6161.708  6088.407  6161.590
# 2021-05-12 15:00:00  6160.747  6187.715  6133.685  6158.469
# 2021-05-12 21:01:00  6085.040  6086.520  5988.556  5993.748
#
# [338 rows x 4 columns]
# RU8888
#                           open       high        low      close
# date
# 2021-03-01 10:00:00  16037.584  16219.945  16035.385  16088.723
# 2021-03-01 11:00:00  16084.818  16119.909  15861.580  15957.627
# 2021-03-01 11:30:00  15959.705  15989.724  15810.095  15834.939
# 2021-03-01 14:00:00  15825.138  15931.276  15782.837  15823.722
# 2021-03-01 15:00:00  15821.544  15961.993  15803.100  15922.970
# ...                        ...        ...        ...        ...
# 2021-05-12 11:00:00  14155.734  14225.357  14146.372  14216.078
# 2021-05-12 11:30:00  14211.342  14289.545  14196.402  14249.964
# 2021-05-12 14:00:00  14267.903  14348.730  14257.251  14319.490
# 2021-05-12 15:00:00  14324.220  14348.372  14238.876  14341.536
# 2021-05-12 21:02:00  14282.809  14292.394  14156.511  14207.403
#
# [338 rows x 4 columns]
# HC8888
#                          open      high       low     close
# date
# 2021-03-01 10:00:00  4852.930  4896.720  4811.986  4842.006
# 2021-03-01 11:00:00  4841.599  4852.318  4805.098  4813.346
# 2021-03-01 11:30:00  4813.812  4817.164  4794.337  4796.662
# 2021-03-01 14:00:00  4799.234  4813.233  4786.723  4811.142
# 2021-03-01 15:00:00  4811.966  4842.061  4803.709  4821.263
# ...                       ...       ...       ...       ...
# 2021-05-12 11:00:00  6578.005  6625.347  6569.632  6619.076
# 2021-05-12 11:30:00  6619.049  6689.023  6598.246  6606.534
# 2021-05-12 14:00:00  6606.129  6690.266  6605.651  6689.364
# 2021-05-12 15:00:00  6689.984  6719.030  6652.372  6675.667
# 2021-05-12 21:02:00  6593.219  6600.495  6545.330  6574.812
#
# [338 rows x 4 columns]
# SS8888
#                           open       high        low      close
# date
# 2021-03-01 10:00:00  15109.954  15273.514  15103.311  15234.628
# 2021-03-01 11:00:00  15235.807  15240.413  15071.461  15132.195
# 2021-03-01 11:30:00  15132.436  15141.891  15008.386  15057.536
# 2021-03-01 14:00:00  15064.534  15115.685  15041.092  15076.030
# 2021-03-01 15:00:00  15072.113  15110.619  15040.399  15074.279
# ...                        ...        ...        ...        ...
# 2021-05-12 11:00:00  15438.960  15552.508  15418.136  15539.037
# 2021-05-12 11:30:00  15538.028  15587.240  15505.777  15536.561
# 2021-05-12 14:00:00  15546.798  15718.036  15543.088  15701.442
# 2021-05-12 15:00:00  15703.523  15850.662  15497.127  15559.455
# 2021-05-12 21:02:00  15519.078  15530.674  15375.005  15469.946
#
# [428 rows x 4 columns]
# P8888
#                          open      high       low     close
# date
# 2021-03-01 10:00:00  7608.365  7612.512  7492.982  7560.823
# 2021-03-01 11:00:00  7559.049  7565.374  7511.525  7544.528
# 2021-03-01 11:30:00  7544.225  7563.197  7515.134  7546.124
# 2021-03-01 14:00:00  7552.653  7564.485  7457.291  7473.034
# 2021-03-01 15:00:00  7470.379  7494.059  7433.015  7438.987
# ...                       ...       ...       ...       ...
# 2021-05-12 11:00:00  8150.145  8163.643  8089.766  8103.953
# 2021-05-12 11:30:00  8101.214  8136.574  8094.089  8113.021
# 2021-05-12 14:00:00  8135.782  8183.035  8133.308  8172.138
# 2021-05-12 15:00:00  8171.843  8267.170  8160.830  8265.327
# 2021-05-12 21:02:00  8215.335  8220.075  8144.567  8151.725
#
# [338 rows x 4 columns]
# J8888
#                          open      high       low     close
# date
# 2021-03-01 10:00:00  2555.112  2555.112  2482.640  2502.050
# 2021-03-01 11:00:00  2502.070  2503.943  2456.017  2466.764
# 2021-03-01 11:30:00  2466.816  2473.186  2444.170  2447.087
# 2021-03-01 14:00:00  2447.850  2452.179  2430.402  2450.769
# 2021-03-01 15:00:00  2450.624  2468.579  2441.912  2452.995
# ...                       ...       ...       ...       ...
# 2021-05-12 11:00:00  2832.245  2899.024  2831.125  2895.821
# 2021-05-12 11:30:00  2894.947  2896.528  2862.213  2870.160
# 2021-05-12 14:00:00  2871.813  2924.493  2871.794  2923.054
# 2021-05-12 15:00:00  2922.455  2922.455  2852.888  2865.348
# 2021-05-12 21:02:00  2829.946  2832.033  2793.870  2818.411
#
# [338 rows x 4 columns]
# Y8888
#                          open      high       low     close
# date
# 2021-03-01 10:00:00  8659.885  8673.428  8586.351  8660.864
# 2021-03-01 11:00:00  8660.264  8670.685  8620.161  8645.810
# 2021-03-01 11:30:00  8645.565  8672.630  8616.341  8659.151
# 2021-03-01 14:00:00  8664.450  8673.577  8582.305  8597.352
# 2021-03-01 15:00:00  8594.194  8617.484  8582.276  8587.821
# ...                       ...       ...       ...       ...
# 2021-05-12 11:00:00  9060.928  9072.065  9004.534  9020.314
# 2021-05-12 11:30:00  9018.646  9051.968  9011.386  9031.929
# 2021-05-12 14:00:00  9053.555  9081.530  9050.084  9067.333
# 2021-05-12 15:00:00  9067.479  9150.576  9056.098  9141.074
# 2021-05-12 21:02:00  9119.014  9119.683  9070.258  9079.198
#
# [338 rows x 4 columns]
# JM8888
#                          open      high       low     close
# date
# 2021-03-01 10:00:00  1486.239  1494.329  1418.912  1429.859
# 2021-03-01 11:00:00  1429.067  1429.447  1392.721  1399.083
# 2021-03-01 11:30:00  1399.106  1407.925  1389.552  1393.176
# 2021-03-01 14:00:00  1395.103  1408.214  1388.535  1408.214
# 2021-03-01 15:00:00  1407.969  1418.497  1402.317  1402.942
# ...                       ...       ...       ...       ...
# 2021-05-12 11:00:00  2026.233  2105.408  2025.310  2098.315
# 2021-05-12 11:30:00  2097.027  2104.431  2081.493  2088.481
# 2021-05-12 14:00:00  2089.860  2118.547  2089.497  2117.869
# 2021-05-12 15:00:00  2117.384  2119.136  2081.269  2093.431
# 2021-05-12 21:02:00  2068.317  2072.243  2047.965  2055.709
#
# [338 rows x 4 columns]
# I8888
#                          open      high       low     close
# date
# 2021-03-01 10:00:00  1121.565  1127.459  1102.865  1111.560
# 2021-03-01 11:00:00  1111.587  1112.486  1091.746  1098.563
# 2021-03-01 11:30:00  1098.463  1105.481  1093.512  1097.894
# 2021-03-01 14:00:00  1097.439  1099.896  1090.979  1099.198
# 2021-03-01 15:00:00  1099.228  1105.637  1096.443  1100.527
# ...                       ...       ...       ...       ...
# 2021-05-12 11:00:00  1259.048  1263.582  1250.420  1262.875
# 2021-05-12 11:30:00  1261.989  1278.814  1258.764  1262.667
# 2021-05-12 14:00:00  1264.183  1304.376  1263.360  1302.058
# 2021-05-12 15:00:00  1301.301  1311.814  1278.391  1292.287
# 2021-05-12 21:02:00  1274.796  1275.134  1249.420  1264.089
#
# [338 rows x 4 columns]
# AP8888
#                          open      high       low     close
# date
# 2021-03-01 10:00:00  6379.332  6423.033  6129.457  6217.809
# 2021-03-01 11:00:00  6218.275  6218.275  6133.019  6161.718
# 2021-03-01 11:30:00  6160.678  6185.157  6136.005  6137.702
# 2021-03-01 14:00:00  6134.903  6153.527  6118.580  6141.003
# 2021-03-01 15:00:00  6141.037  6141.556  6078.883  6093.681
# ...                       ...       ...       ...       ...
# 2021-05-12 10:00:00  5740.351  5756.603  5698.456  5703.294
# 2021-05-12 11:00:00  5703.911  5748.756  5671.034  5734.806
# 2021-05-12 11:30:00  5732.679  5735.769  5712.062  5734.064
# 2021-05-12 14:00:00  5734.864  5747.285  5718.727  5729.019
# 2021-05-12 15:00:00  5728.472  5733.363  5700.981  5724.077
#
# [245 rows x 4 columns]
# CJ8888
#                           open       high        low      close
# date
# 2021-03-01 10:00:00  10711.426  10884.366  10701.983  10852.111
# 2021-03-01 11:00:00  10852.111  10863.959  10766.439  10818.493
# 2021-03-01 11:30:00  10813.813  10870.589  10796.659  10825.508
# 2021-03-01 14:00:00  10825.508  10846.827  10789.775  10811.608
# 2021-03-01 15:00:00  10816.287  10850.863  10767.030  10837.790
# ...                        ...        ...        ...        ...
# 2021-05-12 10:00:00   9014.011   9047.149   8767.343   8801.387
# 2021-05-12 11:00:00   8805.546   8869.921   8796.050   8855.225
# 2021-05-12 11:30:00   8855.908   8870.582   8813.753   8836.294
# 2021-05-12 14:00:00   8835.929   8861.285   8829.310   8851.635
# 2021-05-12 15:00:00   8855.606   8856.210   8807.601   8816.909
#
# [245 rows x 4 columns]
# SR8888
#                          open      high       low     close
# date
# 2021-03-01 10:00:00  5428.636  5476.756  5427.957  5469.919
# 2021-03-01 11:00:00  5470.502  5477.573  5449.382  5453.545
# 2021-03-01 11:30:00  5453.089  5459.191  5437.561  5449.517
# 2021-03-01 14:00:00  5449.634  5463.348  5437.520  5457.227
# 2021-03-01 15:00:00  5456.666  5486.810  5456.025  5486.168
# ...                       ...       ...       ...       ...
# 2021-05-12 11:00:00  5823.923  5836.108  5816.469  5836.080
# 2021-05-12 11:30:00  5835.773  5844.034  5823.942  5825.711
# 2021-05-12 14:00:00  5826.833  5833.506  5818.731  5821.437
# 2021-05-12 15:00:00  5821.272  5821.272  5795.460  5810.392
# 2021-05-12 21:02:00  5770.963  5771.579  5750.887  5761.743
#
# [338 rows x 4 columns]
# CF8888
#                           open       high        low      close
# date
# 2021-03-01 10:00:00  16366.758  16610.511  16366.670  16551.306
# 2021-03-01 11:00:00  16551.289  16658.163  16496.532  16510.346
# 2021-03-01 11:30:00  16508.297  16557.446  16428.136  16513.096
# 2021-03-01 14:00:00  16532.975  16616.523  16532.975  16611.724
# 2021-03-01 15:00:00  16610.770  16743.056  16587.969  16714.516
# ...                        ...        ...        ...        ...
# 2021-05-12 11:00:00  16242.077  16265.031  16184.810  16246.433
# 2021-05-12 11:30:00  16243.006  16255.603  16208.602  16251.516
# 2021-05-12 14:00:00  16250.994  16262.674  16223.915  16253.243
# 2021-05-12 15:00:00  16257.851  16371.761  16174.021  16329.246
# 2021-05-12 21:02:00  16219.820  16224.594  16138.068  16156.508
#
# [338 rows x 4 columns]
# 加载数据完毕
# 启动资金: 8500000.00
# 结束资金: 8500000.00
# Starte Portfolio Value 8500000.0
# 2021-03-17, 做空品种:SS8888,做空价格： 13833.81
# 2021-03-17,  SELL : data_name:SS8888 price : 13842.133 , cost : 209004.25000142702 , commission : 15.109105038778791
# 2021-03-17, open symbol is : SS8888 , price : 13842.133
# Nan
# 2021-03-19, 做空品种:BU8888,做空价格： 2882.17
# Nan
# 2021-03-19, 做空品种:TA8888,做空价格： 4457.37
# Nan
# 2021-03-19, 做空品种:MA8888,做空价格： 2348.51
# Nan
# 2021-03-19, 做空品种:RU8888,做空价格： 14714.03
# Nan
# 2021-03-19, 做空品种:SR8888,做空价格： 5345.77
# 2021-03-19,  SELL : data_name:BU8888 price : 2881.784 , cost : 29204.174199480483 , commission : 10.133301248952284
# 2021-03-19,  SELL : data_name:TA8888 price : 4458.177 , cost : 29203.482043094988 , commission : 6.552273287658736
# 2021-03-19,  SELL : data_name:MA8888 price : 2348.451 , cost : 29199.569273732675 , commission : 12.435932399375075
# 2021-03-19,  SELL : data_name:RU8888 price : 14718.633 , cost : 29205.829165270734 , commission : 1.9849007180420506
# 2021-03-19,  SELL : data_name:SR8888 price : 5345.572 , cost : 29201.701787528276 , commission : 5.463367967732138
# 2021-03-19, open symbol is : BU8888 , price : 2881.784
# 2021-03-19, open symbol is : TA8888 , price : 4458.177
# 2021-03-19, open symbol is : MA8888 , price : 2348.451
# 2021-03-19, open symbol is : RU8888 , price : 14718.633
# 2021-03-19, open symbol is : SR8888 , price : 5345.572
# 2021-03-19, 做空品种:PF8888,做空价格： 7130.38
# 2021-03-19, 做空品种:CF8888,做空价格： 15408.47
# 2021-03-19,  SELL : data_name:PF8888 price : 7128.002 , cost : 123413.6541208623 , commission : 17.309067899139173
# 2021-03-19,  SELL : data_name:CF8888 price : 15409.568 , cost : 218657.1843024648 , commission : 14.191146437075856
# 2021-03-19, open symbol is : PF8888 , price : 7128.002
# 2021-03-19, open symbol is : CF8888 , price : 15409.568
# 2021-03-19, 做空品种:I8888,做空价格： 952.77
# 2021-03-19,  SELL : data_name:I8888 price : 946.558 , cost : 97617.92082892243 , commission : 102.53983280348994
# 2021-03-19, open symbol is : I8888 , price : 946.558
# 2021-03-19, 做多品种:HC8888,做多价格： 5117.90
# 2021-03-22,  BUY : data_name:HC8888 price : 5137.977 , cost : 184562.69209161395 , commission : 36.06853470619776
# 2021-03-22, open symbol is : HC8888 , price : 5137.977
# 2021-03-22, 做多品种:ZN8888,做多价格： 22149.01
# 2021-03-22, 平空品种:SS8888,平空价格： 14247.80
# 2021-03-22, 做空品种:J8888,做空价格： 2160.28
# 2021-03-22,  BUY : data_name:ZN8888 price : 22148.652 , cost : 266298.00862091605 , commission : 12.023026259466162
# 2021-03-22,  BUY : data_name:SS8888 price : 14247.697 , cost : 209004.25000142702 , commission : 15.109105038778791
# 2021-03-22,  SELL : data_name:J8888 price : 2160.145 , cost : 121723.43307752833 , commission : 56.35344123959645
# 2021-03-22, open symbol is : ZN8888 , price : 22148.652
# 2021-03-22, closed symbol is : SS8888 , total_profit : -61277.09075947286 , net_profit : -61307.308969550424
# 2021-03-22, open symbol is : J8888 , price : 2160.145
# 2021-03-23, 平多品种:ZN8888,平多价格： 21766.29
# 2021-03-23,  SELL : data_name:ZN8888 price : 21760.962 , cost : 266298.00862091605 , commission : 12.023026259466162
# 2021-03-23, closed symbol is : ZN8888 , total_profit : -46612.07050532421 , net_profit : -46636.11655784315
# 2021-03-23, 做多品种:SS8888,做多价格： 14279.18
# 2021-03-23,  BUY : data_name:SS8888 price : 14253.341 , cost : 238251.35706733805 , commission : 16.685437150174245
# 2021-03-23, open symbol is : SS8888 , price : 14253.341
# 2021-03-24, 做空品种:FU8888,做空价格： 2315.21
# 2021-03-24,  SELL : data_name:FU8888 price : 2315.797 , cost : 140760.1740423368 , commission : 60.80353090381719
# 2021-03-24, open symbol is : FU8888 , price : 2315.797
# 2021-03-24, 做多品种:RM8888,做多价格： 2849.31
# 2021-03-24, 平空品种:I8888,平空价格： 967.51
# 2021-03-25,  BUY : data_name:RM8888 price : 2852.038 , cost : 182984.7685287938 , commission : 64.2277179813246
# 2021-03-25,  BUY : data_name:I8888 price : 965.846 , cost : 97617.92082892243 , commission : 102.53983280348994
# 2021-03-25, open symbol is : RM8888 , price : 2852.038
# 2021-03-25, closed symbol is : I8888 , total_profit : -19777.88295113715 , net_profit : -19982.96261674413
# 2021-03-25, 平空品种:SR8888,平空价格： 5404.58
# 2021-03-25,  BUY : data_name:SR8888 price : 5404.222 , cost : 29201.701787528276 , commission : 5.463367967732138
# 2021-03-25, closed symbol is : SR8888 , total_profit : -3204.265313074879 , net_profit : -3215.1920490103435
# 2021-03-25, 做空品种:CU8888,做空价格： 65954.67
# 2021-03-25,  SELL : data_name:CU8888 price : 65978.119 , cost : 260996.52099120343 , commission : 3.9572508262001307
# 2021-03-25, open symbol is : CU8888 , price : 65978.119
# 2021-03-25, 做多品种:M8888,做多价格： 3371.20
# 2021-03-25,  BUY : data_name:M8888 price : 3371.781 , cost : 223414.23943178242 , commission : 66.27536025861241
# 2021-03-25, open symbol is : M8888 , price : 3371.781
# 2021-03-26, 做空品种:P8888,做空价格： 7351.23
# 2021-03-26, 做空品种:Y8888,做空价格： 8441.71
# 2021-03-26,  SELL : data_name:P8888 price : 7351.365 , cost : 153478.7080102056 , commission : 20.878616244076397
# 2021-03-26,  SELL : data_name:Y8888 price : 8441.929 , cost : 175981.55303856384 , commission : 20.8484247172804
# 2021-03-26, open symbol is : P8888 , price : 7351.365
# 2021-03-26, open symbol is : Y8888 , price : 8441.929
# 2021-03-26, 做多品种:RB8888,做多价格： 4830.18
# 2021-03-26,  BUY : data_name:RB8888 price : 4830.515 , cost : 183757.5042333902 , commission : 38.045031932378926
# 2021-03-26, open symbol is : RB8888 , price : 4830.515
# 2021-03-26, 做多品种:JD8888,做多价格： 4724.35
# 2021-03-26, 做多品种:UR8888,做多价格： 1982.09
# 2021-03-26, 平空品种:TA8888,平空价格： 4484.32
# 2021-03-26, 做多品种:FG8888,做多价格： 2118.21
# 2021-03-26, 平空品种:J8888,平空价格： 2215.71
# 2021-03-26,  BUY : data_name:TA8888 price : 4492.179 , cost : 29203.482043094988 , commission : 6.552273287658736
# 2021-03-26,  BUY : data_name:FG8888 price : 2118.768 , cost : 162356.18684992712 , commission : 76.65542344189194
# 2021-03-26,  BUY : data_name:J8888 price : 2219.539 , cost : 121723.43307752833 , commission : 56.35344123959645
# 2021-03-26, closed symbol is : TA8888 , total_profit : -2227.90396326975 , net_profit : -2241.0085098450672
# 2021-03-26, open symbol is : FG8888 , price : 2118.768
# 2021-03-26, closed symbol is : J8888 , total_profit : -33470.56288984605 , net_profit : -33583.26977232524
# 2021-03-26, 平空品种:BU8888,平空价格： 2880.94
# 2021-03-26, 做空品种:C8888,做空价格： 2672.81
# 2021-03-26, 平空品种:FU8888,平空价格： 2395.84
# 2021-03-26, 平空品种:CF8888,平空价格： 15014.50
# 2021-03-26,  BUY : data_name:BU8888 price : 2879.632 , cost : 29204.174199480483 , commission : 10.133301248952284
# 2021-03-26,  SELL : data_name:C8888 price : 2672.986 , cost : 374090.49345787626 , commission : 140.00392719231897
# 2021-03-26,  BUY : data_name:FU8888 price : 2396.224 , cost : 140760.1740423368 , commission : 60.80353090381719
# 2021-03-26,  BUY : data_name:CF8888 price : 15015.048 , cost : 218657.1843024648 , commission : 14.191146437075856
# 2021-03-26, closed symbol is : BU8888 , total_profit : 218.06864287745756 , net_profit : 197.802040379553
# 2021-03-26, open symbol is : C8888 , price : 2672.986
# 2021-03-26, closed symbol is : FU8888 , total_profit : -48902.45580001313 , net_profit : -49024.06286182076
# 2021-03-26, closed symbol is : CF8888 , total_profit : 55986.91092355147 , net_profit : 55958.52863067732
# 2021-03-26, 平空品种:CU8888,平空价格： 66629.94
# 2021-03-27,  BUY : data_name:CU8888 price : 66645.767 , cost : 260996.52099120343 , commission : 3.9572508262001307
# 2021-03-27, closed symbol is : CU8888 , total_profit : -26420.50599610869 , net_profit : -26428.420497761093
# 2021-03-29,  BUY : data_name:JD8888 price : 4666.051 , cost : 29371.10748806181 , commission : 6.21742326165576
# 2021-03-29,  BUY : data_name:UR8888 price : 1993.841 , cost : 29371.92165584459 , commission : 14.819334841495758
# 2021-03-29, open symbol is : JD8888 , price : 4666.051
# 2021-03-29, open symbol is : UR8888 , price : 1993.841
# 2021-03-29, 平多品种:JD8888,平多价格： 4600.83
# 2021-03-29, 做多品种:JM8888,做多价格： 1623.76
# 2021-03-29, 做空品种:SR8888,做空价格： 5308.98
# 2021-03-29,  SELL : data_name:JD8888 price : 4600.574 , cost : 29371.10748806181 , commission : 6.21742326165576
# 2021-03-29,  BUY : data_name:JM8888 price : 1623.924 , cost : 143479.26839276688 , commission : 88.4037389973918
# 2021-03-29,  SELL : data_name:SR8888 price : 5308.045 , cost : 338199.263574451 , commission : 63.715008209203276
# 2021-03-29, closed symbol is : JD8888 , total_profit : -4070.98222903439 , net_profit : -4083.4170755577015
# 2021-03-29, open symbol is : JM8888 , price : 1623.924
# 2021-03-29, open symbol is : SR8888 , price : 5308.045
# 2021-03-29, 平空品种:MA8888,平空价格： 2393.94
# 2021-03-29,  BUY : data_name:MA8888 price : 2394.002 , cost : 29199.569273732675 , commission : 12.435932399375075
# 2021-03-29, closed symbol is : MA8888 , total_profit : -5664.691567239332 , net_profit : -5689.563432038081
# 2021-03-30, 平多品种:RM8888,平多价格： 2813.66
# 2021-03-31,  SELL : data_name:RM8888 price : 2797.995 , cost : 182984.7685287938 , commission : 64.2277179813246
# 2021-03-31, closed symbol is : RM8888 , total_profit : -34710.58562864733 , net_profit : -34839.04106460998
# 2021-03-31, 平多品种:UR8888,平多价格： 1921.00
# 2021-03-31, 做空品种:AP8888,做空价格： 5517.97
# 2021-03-31,  SELL : data_name:UR8888 price : 1920.999 , cost : 29371.92165584459 , commission : 14.819334841495758
# 2021-03-31,  SELL : data_name:AP8888 price : 5516.516 , cost : 154212.34493341323 , commission : 27.95221042838739
# 2021-03-31, closed symbol is : UR8888 , total_profit : -10794.69988524232 , net_profit : -10824.338554925313
# 2021-03-31, open symbol is : AP8888 , price : 5516.516
# 2021-03-31, 平多品种:SS8888,平多价格： 14308.98
# 2021-03-31,  SELL : data_name:SS8888 price : 14304.813 , cost : 238251.35706733805 , commission : 16.685437150174245
# 2021-03-31, closed symbol is : SS8888 , total_profit : 8588.328209937647 , net_profit : 8554.957335637298
# 2021-04-01, 做多品种:RM8888,做多价格： 2943.57
# 2021-04-01,  BUY : data_name:RM8888 price : 2944.119 , cost : 205145.09841742105 , commission : 69.70611567020762
# 2021-04-01, open symbol is : RM8888 , price : 2944.119
# 2021-04-01, 平空品种:P8888,平空价格： 7182.46
# 2021-04-01, 平空品种:Y8888,平空价格： 8306.83
# 2021-04-01, 平多品种:JM8888,平多价格： 1598.71
# 2021-04-01,  BUY : data_name:P8888 price : 7184.784 , cost : 153478.7080102056 , commission : 20.878616244076397
# 2021-04-01,  BUY : data_name:Y8888 price : 8306.019 , cost : 175981.55303856384 , commission : 20.8484247172804
# 2021-04-01,  SELL : data_name:JM8888 price : 1598.655 , cost : 143479.26839276688 , commission : 88.4037389973918
# 2021-04-01, closed symbol is : P8888 , total_profit : 34779.80772554493 , net_profit : 34738.05049305678
# 2021-04-01, closed symbol is : Y8888 , total_profit : 28335.09403325576 , net_profit : 28293.3971838212
# 2021-04-01, closed symbol is : JM8888 , total_profit : -22338.74080725094 , net_profit : -22515.54828524572
# 2021-04-01, 做空品种:CU8888,做空价格： 65155.06
# 2021-04-01,  SELL : data_name:CU8888 price : 65455.481 , cost : 293869.12415648665 , commission : 4.510308098480341
# 2021-04-01, open symbol is : CU8888 , price : 65455.481
# 2021-04-01, 做多品种:J8888,做多价格： 2387.64
# 2021-04-01,  BUY : data_name:J8888 price : 2387.792 , cost : 143026.66982418133 , commission : 59.91900704825359
# 2021-04-01, open symbol is : J8888 , price : 2387.792
# 2021-04-02, 做空品种:ZN8888,做空价格： 21321.39
# 2021-04-02, 做空品种:CJ8888,做空价格： 9929.35
# 2021-04-02,  SELL : data_name:ZN8888 price : 21320.037 , cost : 281292.8579347422 , commission : 13.193230051814746
# 2021-04-02,  SELL : data_name:CJ8888 price : 9923.921 , cost : 272919.96704574383 , commission : 27.487155508686055
# 2021-04-02, open symbol is : ZN8888 , price : 21320.037
# 2021-04-02, open symbol is : CJ8888 , price : 9923.921
# 2021-04-02, 平空品种:CU8888,平空价格： 66404.76
# 2021-04-02, 平空品种:RU8888,平空价格： 14276.57
# 2021-04-02,  BUY : data_name:CU8888 price : 66408.498 , cost : 293869.12415648665 , commission : 4.510308098480341
# 2021-04-02,  BUY : data_name:RU8888 price : 14282.11 , cost : 29205.829165270734 , commission : 1.9849007180420506
# 2021-04-02, closed symbol is : CU8888 , total_profit : -42984.00293089471 , net_profit : -42993.023547091674
# 2021-04-02, closed symbol is : RU8888 , total_profit : 8664.548161418685 , net_profit : 8660.5783599826
# 2021-04-02, 做多品种:AL8888,做多价格： 17549.72
# 2021-04-02,  BUY : data_name:AL8888 price : 17547.008 , cost : 253779.55435143333 , commission : 14.461197467173818
# 2021-04-02, open symbol is : AL8888 , price : 17547.008
# 2021-04-02, 平空品种:PF8888,平空价格： 7165.06
# 2021-04-06,  BUY : data_name:PF8888 price : 7121.571 , cost : 123413.6541208623 , commission : 17.309067899139173
# 2021-04-06, closed symbol is : PF8888 , total_profit : 1113.1461565937257 , net_profit : 1078.5280207954472
# 2021-04-06, 平空品种:ZN8888,平空价格： 21797.24
# 2021-04-06, 平空品种:CJ8888,平空价格： 10126.92
# 2021-04-06, 平空品种:SR8888,平空价格： 5370.68
# 2021-04-06,  BUY : data_name:ZN8888 price : 21803.26 , cost : 281292.8579347422 , commission : 13.193230051814746
# 2021-04-06,  BUY : data_name:CJ8888 price : 10129.197 , cost : 272919.96704574383 , commission : 27.487155508686055
# 2021-04-06,  BUY : data_name:SR8888 price : 5370.061 , cost : 338199.263574451 , commission : 63.715008209203276
# 2021-04-06, closed symbol is : ZN8888 , total_profit : -63752.72205328052 , net_profit : -63779.108513384155
# 2021-04-06, closed symbol is : CJ8888 , total_profit : -56424.53334201034 , net_profit : -56479.507653027715
# 2021-04-06, closed symbol is : SR8888 , total_profit : -39513.49949101926 , net_profit : -39640.92950743767
# 2021-04-06, 做多品种:MA8888,做多价格： 2443.24
# 2021-04-06,  BUY : data_name:MA8888 price : 2441.815 , cost : 190320.70891156432 , commission : 77.90450630845858
# 2021-04-06, open symbol is : MA8888 , price : 2441.815
# 2021-04-06, 做多品种:TA8888,做多价格： 4635.48
# 2021-04-07,  BUY : data_name:TA8888 price : 4601.24 , cost : 159613.41175250287 , commission : 34.43655053991432
# 2021-04-07, open symbol is : TA8888 , price : 4601.24
# 2021-04-07, 平空品种:C8888,平空价格： 2646.70
# 2021-04-07,  BUY : data_name:C8888 price : 2646.296 , cost : 374090.49345787626 , commission : 140.00392719231897
# 2021-04-07, closed symbol is : C8888 , total_profit : 37367.04816763001 , net_profit : 37087.04031324537
# 2021-04-07, 做空品种:SA8888,做空价格： 1932.51
# 2021-04-07, 做空品种:FU8888,做空价格： 2331.39
# 2021-04-07,  SELL : data_name:SA8888 price : 1932.355 , cost : 145533.51228974547 , commission : 75.32790491187654
# 2021-04-07,  SELL : data_name:FU8888 price : 2330.989 , cost : 148675.83334433573 , commission : 63.781996286716314
# 2021-04-07, open symbol is : SA8888 , price : 1932.355
# 2021-04-07, open symbol is : FU8888 , price : 2330.989
# 2021-04-07, 平多品种:HC8888,平多价格： 5434.89
# 2021-04-07,  SELL : data_name:HC8888 price : 5435.387 , cost : 184562.69209161395 , commission : 36.06853470619776
# 2021-04-07, closed symbol is : HC8888 , total_profit : 107271.4290697027 , net_profit : 107199.29200029031
# 2021-04-07, 做空品种:BU8888,做空价格： 2816.00
# 2021-04-08,  SELL : data_name:BU8888 price : 2826.6210000000005 , cost : 144382.90031651995 , commission : 51.27233676012782
# 2021-04-08, open symbol is : BU8888 , price : 2826.6210000000005
# 2021-04-08, 平空品种:AP8888,平空价格： 5812.12
# 2021-04-08,  BUY : data_name:AP8888 price : 5813.142 , cost : 154212.34493341323 , commission : 27.95221042838739
# 2021-04-08, closed symbol is : AP8888 , total_profit : -82913.52370530844 , net_profit : -82969.42812616522
# 2021-04-08, 平多品种:TA8888,平多价格： 4479.28
# 2021-04-08,  SELL : data_name:TA8888 price : 4491.852 , cost : 159613.41175250287 , commission : 34.43655053991432
# 2021-04-08, closed symbol is : TA8888 , total_profit : -37669.453904601454 , net_profit : -37738.32700568128
# 2021-04-08, 做多品种:ZN8888,做多价格： 22107.76
# 2021-04-09,  BUY : data_name:ZN8888 price : 22110.578 , cost : 302419.21006569674 , commission : 13.679794185809778
# 2021-04-09, open symbol is : ZN8888 , price : 22110.578
# 2021-04-09, 做空品种:JD8888,做空价格： 4417.72
# 2021-04-09,  SELL : data_name:JD8888 price : 4416.82 , cost : 196699.3408367745 , commission : 44.5323388808636
# 2021-04-09, open symbol is : JD8888 , price : 4416.82
# 2021-04-09, 做空品种:RU8888,做空价格： 13734.65
# 2021-04-09,  SELL : data_name:RU8888 price : 13734.073000000002 , cost : 171745.02556737923 , commission : 12.505098701571226
# 2021-04-09, open symbol is : RU8888 , price : 13734.073000000002
# 2021-04-09, 平多品种:FG8888,平多价格： 2086.86
# 2021-04-09,  SELL : data_name:FG8888 price : 2093.036 , cost : 162356.18684992712 , commission : 76.65542344189194
# 2021-04-09, closed symbol is : FG8888 , total_profit : -19724.973560067614 , net_profit : -19878.2844069514
# 2021-04-12, 平多品种:MA8888,平多价格： 2365.76
# 2021-04-12, 平多品种:ZN8888,平多价格： 21647.43
# 2021-04-12, 平多品种:RB8888,平多价格： 4974.27
# 2021-04-12,  SELL : data_name:MA8888 price : 2366.225 , cost : 190320.70891156432 , commission : 77.90450630845858
# 2021-04-12,  SELL : data_name:ZN8888 price : 21640.084 , cost : 302419.21006569674 , commission : 13.679794185809778
# 2021-04-12,  SELL : data_name:RB8888 price : 4973.184 , cost : 183757.5042333902 , commission : 38.045031932378926
# 2021-04-12, closed symbol is : MA8888 , total_profit : -58888.016318563954 , net_profit : -59043.82533118087
# 2021-04-12, closed symbol is : ZN8888 , total_profit : -64362.610856584186 , net_profit : -64389.970444955805
# 2021-04-12, closed symbol is : RB8888 , total_profit : 54278.466607605646 , net_profit : 54202.37654374089
# 2021-04-12, 平多品种:M8888,平多价格： 3442.84
# 2021-04-12,  SELL : data_name:M8888 price : 3439.958 , cost : 223414.23943178242 , commission : 66.27536025861241
# 2021-04-12, closed symbol is : M8888 , total_profit : 45184.55236351427 , net_profit : 45052.00164299704
# 2021-04-12, 平多品种:RM8888,平多价格： 2876.09
# 2021-04-12, 做空品种:PF8888,做空价格： 6883.82
# 2021-04-12,  SELL : data_name:RM8888 price : 2876.122 , cost : 205145.09841742105 , commission : 69.70611567020762
# 2021-04-12,  SELL : data_name:PF8888 price : 6884.417000000001 , cost : 149540.1481490961 , commission : 21.726013097355235
# 2021-04-12, closed symbol is : RM8888 , total_profit : -47398.06747227129 , net_profit : -47537.4797036117
# 2021-04-12, open symbol is : PF8888 , price : 6884.417000000001
# 2021-04-12, 做空品种:SS8888,做空价格： 14064.81
# 2021-04-12, 做多品种:I8888,做多价格： 1020.65
# 2021-04-12,  SELL : data_name:SS8888 price : 14070.762000000002 , cost : 281192.81804426963 , commission : 19.993801055479924
# 2021-04-12,  BUY : data_name:I8888 price : 1017.694 , cost : 113146.1431173083 , commission : 110.92759129147872
# 2021-04-12, open symbol is : SS8888 , price : 14070.762000000002
# 2021-04-12, open symbol is : I8888 , price : 1017.694
# 2021-04-12, 做空品种:P8888,做空价格： 6871.40
# 2021-04-12,  SELL : data_name:P8888 price : 6869.706999999999 , cost : 144243.14743610253 , commission : 20.99303557504039
# 2021-04-12, open symbol is : P8888 , price : 6869.706999999999
# 2021-04-13, 做多品种:FG8888,做多价格： 2160.48
# 2021-04-13,  BUY : data_name:FG8888 price : 2160.652 , cost : 180244.02617009697 , commission : 83.44630841208193
# 2021-04-13, open symbol is : FG8888 , price : 2160.652
# 2021-04-13, 平空品种:JD8888,平空价格： 4514.42
# 2021-04-13,  BUY : data_name:JD8888 price : 4515.601 , cost : 196699.3408367745 , commission : 44.5323388808636
# 2021-04-13, closed symbol is : JD8888 , total_profit : -43989.48966990585 , net_profit : -44078.55434766758
# 2021-04-13, 平空品种:FU8888,平空价格： 2354.92
# 2021-04-13,  BUY : data_name:FU8888 price : 2355.247 , cost : 148675.83334433573 , commission : 63.781996286716314
# 2021-04-13, closed symbol is : FU8888 , total_profit : -15472.236659231523 , net_profit : -15599.800651804955
# 2021-04-14, 平空品种:BU8888,平空价格： 2862.74
# 2021-04-14,  BUY : data_name:BU8888 price : 2864.624 , cost : 144382.90031651995 , commission : 51.27233676012782
# 2021-04-14, closed symbol is : BU8888 , total_profit : -19485.02613895099 , net_profit : -19587.570812471247
# 2021-04-14, 做多品种:CU8888,做多价格： 67233.17
# 2021-04-15,  BUY : data_name:CU8888 price : 67241.695 , cost : 328345.1323151034 , commission : 4.883690037854973
# 2021-04-15, open symbol is : CU8888 , price : 67241.695
# 2021-04-15, 平空品种:PF8888,平空价格： 7095.60
# 2021-04-15, 做多品种:CJ8888,做多价格： 10246.05
# 2021-04-15,  BUY : data_name:PF8888 price : 7096.872000000001 , cost : 149540.1481490961 , commission : 21.726013097355235
# 2021-04-15,  BUY : data_name:CJ8888 price : 10248.712 , cost : 280118.65479405946 , commission : 27.339318250445
# 2021-04-15, closed symbol is : PF8888 , total_profit : -46158.001125985844 , net_profit : -46201.453152180555
# 2021-04-15, open symbol is : CJ8888 , price : 10248.712
# 2021-04-15, 做多品种:TA8888,做多价格： 4641.22
# 2021-04-15,  BUY : data_name:TA8888 price : 4639.608 , cost : 173969.87073025026 , commission : 37.48542786689297
# 2021-04-15, open symbol is : TA8888 , price : 4639.608
# 2021-04-15, 做多品种:C8888,做多价格： 2683.76
# 2021-04-15,  BUY : data_name:C8888 price : 2683.633 , cost : 363817.0327527885 , commission : 135.60083218516158
# 2021-04-15, open symbol is : C8888 , price : 2683.633
# 2021-04-15, 平空品种:P8888,平空价格： 7062.47
# 2021-04-15,  BUY : data_name:P8888 price : 7062.518 , cost : 144243.14743610253 , commission : 20.99303557504039
# 2021-04-15, closed symbol is : P8888 , total_profit : -40476.881822591255 , net_profit : -40518.867893741335
# 2021-04-15, 做多品种:CF8888,做多价格： 15266.41
# 2021-04-16,  BUY : data_name:CF8888 price : 15294.787 , cost : 233542.4113177493 , commission : 15.298205903167123
# 2021-04-16, open symbol is : CF8888 , price : 15294.787
# 2021-04-16, 做多品种:MA8888,做多价格： 2469.48
# 2021-04-16,  BUY : data_name:MA8888 price : 2470.364 , cost : 200110.96156364068 , commission : 81.04939715011773
# 2021-04-16, open symbol is : MA8888 , price : 2470.364
# 2021-04-16, 平多品种:AL8888,平多价格： 18027.90
# 2021-04-16, 平空品种:RU8888,平空价格： 13852.75
# 2021-04-16, 做多品种:SR8888,做多价格： 5409.80
# 2021-04-16,  SELL : data_name:AL8888 price : 18028.834 , cost : 253779.55435143333 , commission : 14.461197467173818
# 2021-04-16,  BUY : data_name:RU8888 price : 13849.658 , cost : 171745.02556737923 , commission : 12.505098701571226
# 2021-04-16,  BUY : data_name:SR8888 price : 5409.299 , cost : 410097.1272838506 , commission : 75.81754987684427
# 2021-04-16, closed symbol is : AL8888 , total_profit : 69677.80930818453 , net_profit : 69648.88691325019
# 2021-04-16, closed symbol is : RU8888 , total_profit : -14454.018334210767 , net_profit : -14479.028531613909
# 2021-04-16, open symbol is : SR8888 , price : 5409.299
# 2021-04-16, 平空品种:SA8888,平空价格： 1922.55
# 2021-04-19,  BUY : data_name:SA8888 price : 1923.1910000000003 , cost : 145533.51228974547 , commission : 75.32790491187654
# 2021-04-19, closed symbol is : SA8888 , total_profit : 6903.049206124357 , net_profit : 6752.393396300604
# 2021-04-19, 做多品种:UR8888,做多价格： 2013.42
# 2021-04-19, 做空品种:RU8888,做空价格： 13422.04
# 2021-04-19,  BUY : data_name:UR8888 price : 2013.8669999999997 , cost : 204704.39306175156 , commission : 101.69120370678169
# 2021-04-19,  SELL : data_name:RU8888 price : 13417.960999999998 , cost : 181258.89401478937 , commission : 13.504611385396318
# 2021-04-19, open symbol is : UR8888 , price : 2013.8669999999997
# 2021-04-19, open symbol is : RU8888 , price : 13417.960999999998
# 2021-04-19, 做多品种:FU8888,做多价格： 2548.14
# 2021-04-19,  BUY : data_name:FU8888 price : 2559.069 , cost : 177896.4297815563 , commission : 69.81806506340514
# 2021-04-19, open symbol is : FU8888 , price : 2559.069
# 2021-04-19, 做多品种:M8888,做多价格： 3506.75
# 2021-04-19, 平空品种:RU8888,平空价格： 13851.58
# 2021-04-19,  BUY : data_name:M8888 price : 3506.07 , cost : 260811.945996834 , commission : 74.39017284564575
# 2021-04-19,  BUY : data_name:RU8888 price : 13847.911 , cost : 181258.89401478937 , commission : 13.504611385396318
# 2021-04-19, open symbol is : M8888 , price : 3506.07
# 2021-04-19, closed symbol is : RU8888 , total_profit : -58063.07665151181 , net_profit : -58090.0858742826
# 2021-04-20, 做多品种:RB8888,做多价格： 5155.82
# 2021-04-20,  BUY : data_name:RB8888 price : 5146.432 , cost : 218484.8039127417 , commission : 42.38308514311188
# 2021-04-20, open symbol is : RB8888 , price : 5146.432
# 2021-04-20, 平多品种:FU8888,平多价格： 2494.26
# 2021-04-21, 平多品种:CU8888,平多价格： 68640.72
# 2021-04-21,  SELL : data_name:FU8888 price : 2507.694 , cost : 177896.4297815563 , commission : 69.81806506340514
# 2021-04-21,  SELL : data_name:CU8888 price : 68700.971 , cost : 328345.1323151034 , commission : 4.883690037854973
# ...
# 2021-04-27, open symbol is : SS8888 , price : 14364.224
# 2021-04-27, 做多品种:SA8888,做多价格： 1980.01
# 2021-04-27,  BUY : data_name:SA8888 price : 1980.179 , cost : 184417.08657979555 , commission : 93.13994271706846
# 2021-04-27, open symbol is : SA8888 , price : 1980.179
# 2021-04-27, 做多品种:TA8888,做多价格： 4768.69
# 2021-04-27,  BUY : data_name:TA8888 price : 4780.507 , cost : 209701.62540233883 , commission : 43.98104559612811
# 2021-04-27, open symbol is : TA8888 , price : 4780.507
# 2021-04-28, 平多品种:M8888,平多价格： 3571.63
# 2021-04-28, 平多品种:RM8888,平多价格： 2973.78
# 2021-04-28, 平多品种:CU8888,平多价格： 71316.21
# 2021-04-28,  SELL : data_name:M8888 price : 3571.348 , cost : 260811.945996834 , commission : 74.39017284564575
# 2021-04-28,  SELL : data_name:RM8888 price : 2973.576 , cost : 243552.35564968854 , commission : 79.3847313069389
# 2021-04-28,  SELL : data_name:CU8888 price : 71301.736 , cost : 351602.9204388345 , commission : 5.034333993482833
# 2021-04-28, closed symbol is : M8888 , total_profit : 48560.41703018048 , net_profit : 48411.63668448919
# 2021-04-28, closed symbol is : RM8888 , total_profit : -75736.20905607198 , net_profit : -75894.97851868586
# 2021-04-28, closed symbol is : CU8888 , total_profit : 73735.02043216732 , net_profit : 73724.95176418035
# 2021-04-28, 平多品种:SS8888,平多价格： 14290.05
# 2021-04-28, 平多品种:JM8888,平多价格： 1719.19
# 2021-04-28, 平多品种:I8888,平多价格： 1087.64
# 2021-04-28,  SELL : data_name:SS8888 price : 14288.775 , cost : 384483.6609211728 , commission : 26.770899660296116
# 2021-04-28,  SELL : data_name:JM8888 price : 1718.439 , cost : 170405.49279624317 , commission : 98.21642236094706
# 2021-04-28,  SELL : data_name:I8888 price : 1087.184 , cost : 113146.1431173083 , commission : 110.92759129147872
# 2021-04-28, closed symbol is : SS8888 , total_profit : -20198.376084696956 , net_profit : -20251.91788401755
# 2021-04-28, closed symbol is : JM8888 , total_profit : -17241.892945464097 , net_profit : -17438.32579018599
# 2021-04-28, closed symbol is : I8888 , total_profit : 77083.58318844857 , net_profit : 76861.7280058656
# 2021-04-29, 做多品种:CU8888,做多价格： 72812.26
# 2021-04-29,  BUY : data_name:CU8888 price : 72818.057 , cost : 364632.08351822133 , commission : 5.007856994976396
# 2021-04-29, open symbol is : CU8888 , price : 72818.057
# 2021-04-29, 做空品种:CJ8888,做空价格： 9690.94
# 2021-04-29,  SELL : data_name:CJ8888 price : 9690.211 , cost : 303525.644724659 , commission : 31.323595946817232
# 2021-04-29, open symbol is : CJ8888 , price : 9690.211
# 2021-04-29, 做多品种:PF8888,做多价格： 7244.75
# 2021-04-29,  BUY : data_name:PF8888 price : 7271.242 , cost : 210717.16755712376 , commission : 29.08851015421366
# 2021-04-29, open symbol is : PF8888 , price : 7271.242
# 2021-04-29, 做多品种:BU8888,做多价格： 3025.34
# 2021-04-29, 平多品种:ZN8888,平多价格： 22062.26
# 2021-04-29,  BUY : data_name:BU8888 price : 3025.054 , cost : 196872.96957192456 , commission : 65.08197341220647
# 2021-04-29,  SELL : data_name:ZN8888 price : 22061.931 , cost : 381617.81535616756 , commission : 17.288113407455267
# 2021-04-29, open symbol is : BU8888 , price : 3025.054
# 2021-04-29, closed symbol is : ZN8888 , total_profit : -2383.6850766200128 , net_profit : -2418.2613034349233
# 2021-04-29, 平多品种:J8888,平多价格： 2631.58
# 2021-04-29, 平多品种:SR8888,平多价格： 5504.92
# 2021-04-29, 平多品种:CF8888,平多价格： 15631.57
# 2021-04-30,  SELL : data_name:J8888 price : 2634.9 , cost : 143026.66982418133 , commission : 59.91900704825359
# 2021-04-30,  SELL : data_name:SR8888 price : 5505.979 , cost : 410097.1272838506 , commission : 75.81754987684427
# 2021-04-30,  SELL : data_name:CF8888 price : 15622.563 , cost : 233542.4113177493 , commission : 15.298205903167123
# 2021-04-30, closed symbol is : J8888 , total_profit : 148064.6599367986 , net_profit : 147944.82192270207
# 2021-04-30, closed symbol is : SR8888 , total_profit : 73300.40722093325 , net_profit : 73148.77212117956
# 2021-04-30, closed symbol is : CF8888 , total_profit : 50143.84738116504 , net_profit : 50113.250969358705
# 2021-04-30, 平多品种:C8888,平多价格： 2728.49
# 2021-04-30,  SELL : data_name:C8888 price : 2728.422 , cost : 363817.0327527885 , commission : 135.60083218516158
# 2021-04-30, closed symbol is : C8888 , total_profit : 60734.256727412314 , net_profit : 60463.05506304199
# 2021-04-30, 平多品种:CU8888,平多价格： 71869.92
# 2021-04-30,  SELL : data_name:CU8888 price : 71868.835 , cost : 364632.08351822133 , commission : 5.007856994976396
# 2021-04-30, closed symbol is : CU8888 , total_profit : -47535.680324854555 , net_profit : -47545.69603884451
# 2021-05-06, 平多品种:JD8888,平多价格： 4683.16
# 2021-05-06, 做多品种:MA8888,做多价格： 2511.07
# 2021-05-06, 做多品种:FU8888,做多价格： 2587.38
# 2021-05-06, 做多品种:CU8888,做多价格： 73203.18
# 2021-05-06, 做多品种:RU8888,做多价格： 14360.17
# 2021-05-06, 做多品种:SS8888,做多价格： 14863.70
# 2021-05-06, 做多品种:P8888,做多价格： 7795.90
# 2021-05-06, 做多品种:J8888,做多价格： 2756.99
# 2021-05-06, 做多品种:Y8888,做多价格： 8782.45
# 2021-05-06, 做多品种:JM8888,做多价格： 1848.42
# 2021-05-06,  SELL : data_name:JD8888 price : 4683.08 , cost : 219964.96761045215 , commission : 46.17232737415033
# 2021-05-06,  BUY : data_name:MA8888 price : 2511.137 , cost : 228303.26838084383 , commission : 90.9212538354615
# 2021-05-06,  BUY : data_name:FU8888 price : 2588.382 , cost : 201461.05025618844 , commission : 77.8743912857319
# 2021-05-06,  BUY : data_name:CU8888 price : 73209.967 , cost : 356771.0941627197 , commission : 4.873722308685705
# 2021-05-06,  BUY : data_name:RU8888 price : 14356.29 , cost : 215136.94143055513 , commission : 14.981681158116652
# 2021-05-06,  BUY : data_name:SS8888 price : 14864.097 , cost : 359407.1248050135 , commission : 24.18133114478998
# 2021-05-06,  BUY : data_name:P8888 price : 7796.285 , cost : 189708.6327730065 , commission : 24.33722036857043
# 2021-05-06,  BUY : data_name:J8888 price : 2758.007 , cost : 186665.88776136684 , commission : 67.73072850557578
# 2021-05-06,  BUY : data_name:Y8888 price : 8782.487 , cost : 217132.98119411684 , commission : 24.724775813495427
# 2021-05-06,  BUY : data_name:JM8888 price : 1849.044 , cost : 185642.5829330933 , commission : 100.45594314561326
# 2021-05-06, closed symbol is : JD8888 , total_profit : -37971.198585953876 , net_profit : -38063.54324070218
# 2021-05-06, open symbol is : MA8888 , price : 2511.137
# 2021-05-06, open symbol is : FU8888 , price : 2588.382
# 2021-05-06, open symbol is : CU8888 , price : 73209.967
# 2021-05-06, open symbol is : RU8888 , price : 14356.29
# 2021-05-06, open symbol is : SS8888 , price : 14864.097
# 2021-05-06, open symbol is : P8888 , price : 7796.285
# 2021-05-06, open symbol is : J8888 , price : 2758.007
# 2021-05-06, open symbol is : Y8888 , price : 8782.487
# 2021-05-06, open symbol is : JM8888 , price : 1849.044
# 2021-05-06, 做多品种:RM8888,做多价格： 3082.87
# 2021-05-06,  BUY : data_name:RM8888 price : 3082.91 , cost : 246783.2892885512 , commission : 80.07244947714186
# 2021-05-06, open symbol is : RM8888 , price : 3082.91
# 2021-05-06, 做多品种:I8888,做多价格： 1138.55
# 2021-05-06,  BUY : data_name:I8888 price : 1138.498 , cost : 157109.1676781058 , commission : 138.0572650949963
# 2021-05-06, open symbol is : I8888 , price : 1138.498
# 2021-05-06, 做多品种:SR8888,做多价格： 5593.85
# 2021-05-06,  BUY : data_name:SR8888 price : 5592.847 , cost : 481068.6565790043 , commission : 86.0126330375477
# 2021-05-06, open symbol is : SR8888 , price : 5592.847
# 2021-05-06, 做多品种:CF8888,做多价格： 15992.26
# 2021-05-06,  BUY : data_name:CF8888 price : 15996.802 , cost : 309026.37957517966 , commission : 19.32381062876311
# 2021-05-06, open symbol is : CF8888 , price : 15996.802
# 2021-05-06, 做多品种:M8888,做多价格： 3669.53
# 2021-05-07,  BUY : data_name:M8888 price : 3691.8199999999997 , cost : 309458.69425888435 , commission : 84.34415215559672
# 2021-05-07, open symbol is : M8888 , price : 3691.8199999999997
# 2021-05-07, 做多品种:C8888,做多价格： 2801.33
# 2021-05-07,  BUY : data_name:C8888 price : 2801.277 , cost : 458740.0430346052 , commission : 163.7772377845788
# 2021-05-07, open symbol is : C8888 , price : 2801.277
# 2021-05-07, 平多品种:SA8888,平多价格： 2103.88
# 2021-05-07, 做多品种:ZN8888,做多价格： 22715.50
# 2021-05-07, 平多品种:SS8888,平多价格： 14790.65
# 2021-05-07,  SELL : data_name:SA8888 price : 2103.508 , cost : 184417.08657979555 , commission : 93.13994271706846
# 2021-05-07,  BUY : data_name:ZN8888 price : 22720.508 , cost : 364738.4910312975 , commission : 16.057164474193154
# 2021-05-07,  SELL : data_name:SS8888 price : 14791.939000000002 , cost : 359407.1248050135 , commission : 24.18133114478998
# 2021-05-07, closed symbol is : SA8888 , total_profit : 114868.55995353311 , net_profit : 114682.28006809897
# 2021-05-07, open symbol is : ZN8888 , price : 22720.508
# 2021-05-07, closed symbol is : SS8888 , total_profit : -17448.764927457418 , net_profit : -17497.127589746997
# 2021-05-07, 平多品种:M8888,平多价格： 3648.71
# 2021-05-07, 平多品种:RM8888,平多价格： 3092.53
# 2021-05-07, 平多品种:FU8888,平多价格： 2520.62
# 2021-05-10,  SELL : data_name:M8888 price : 3669.585 , cost : 309458.69425888435 , commission : 84.34415215559672
# 2021-05-10,  SELL : data_name:RM8888 price : 3104.844 , cost : 246783.2892885512 , commission : 80.07244947714186
# 2021-05-10,  SELL : data_name:FU8888 price : 2546.576 , cost : 201461.05025618844 , commission : 77.8743912857319
# 2021-05-10, closed symbol is : M8888 , total_profit : -18753.922231796652 , net_profit : -18922.610536107844
# 2021-05-10, closed symbol is : RM8888 , total_profit : 17563.091068316455 , net_profit : 17402.94616936217
# 2021-05-10, closed symbol is : FU8888 , total_profit : -32556.16802091311 , net_profit : -32711.91680348457
# 2021-05-10, 做多品种:JD8888,做多价格： 4816.75
# 2021-05-10, 做多品种:SS8888,做多价格： 15357.71
# 2021-05-10,  BUY : data_name:JD8888 price : 4816.971 , cost : 309919.4744102241 , commission : 64.35205033434886
# 2021-05-10,  BUY : data_name:SS8888 price : 15360.701999999997 , cost : 394784.24318987364 , commission : 25.707120087899565
# 2021-05-10, open symbol is : JD8888 , price : 4816.971
# 2021-05-10, open symbol is : SS8888 , price : 15360.701999999997
# 2021-05-10, 做多品种:SA8888,做多价格： 2200.59
# 2021-05-10,  BUY : data_name:SA8888 price : 2200.445 , cost : 220701.42584137004 , commission : 100.31882992789548
# 2021-05-10, open symbol is : SA8888 , price : 2200.445
# 2021-05-10, 平多品种:AL8888,平多价格： 19836.87
# 2021-05-10, 平多品种:CU8888,平多价格： 75893.54
# 2021-05-10, 平多品种:ZN8888,平多价格： 22578.54
# 2021-05-10, 平多品种:J8888,平多价格： 2886.16
# 2021-05-10,  SELL : data_name:AL8888 price : 19836.006 , cost : 299192.27652004303 , commission : 16.37525458486361
# 2021-05-10,  SELL : data_name:CU8888 price : 75869.79 , cost : 356771.0941627197 , commission : 4.873722308685705
# 2021-05-10,  SELL : data_name:ZN8888 price : 22575.373 , cost : 364738.4910312975 , commission : 16.057164474193154
# 2021-05-10,  SELL : data_name:J8888 price : 2885.535 , cost : 186665.88776136684 , commission : 67.73072850557578
# 2021-05-10, closed symbol is : AL8888 , total_profit : 256158.92623375077 , net_profit : 256126.17572458103
# 2021-05-10, closed symbol is : CU8888 , total_profit : 129632.38692255286 , net_profit : 129622.63947793549
# 2021-05-10, closed symbol is : ZN8888 , total_profit : -23304.565659620563 , net_profit : -23336.67998856895
# 2021-05-10, closed symbol is : J8888 , total_profit : 86375.64344859055 , net_profit : 86240.1819915794
# 2021-05-10, 平多品种:BU8888,平多价格： 3021.33
# 2021-05-10, 平多品种:RU8888,平多价格： 14194.23
# 2021-05-10, 平多品种:Y8888,平多价格： 8758.01
# 2021-05-10, 平多品种:JM8888,平多价格： 1964.17
# 2021-05-10, 平多品种:I8888,平多价格： 1236.40
# 2021-05-10, 平多品种:CF8888,平多价格： 15837.61
# 2021-05-11,  SELL : data_name:BU8888 price : 3025.513 , cost : 196872.96957192456 , commission : 65.08197341220647
# 2021-05-11,  SELL : data_name:RU8888 price : 14206.641 , cost : 215136.94143055513 , commission : 14.981681158116652
# 2021-05-11,  SELL : data_name:Y8888 price : 8729.3 , cost : 217132.98119411684 , commission : 24.724775813495427
# 2021-05-11,  SELL : data_name:JM8888 price : 1962.6949999999997 , cost : 185642.5829330933 , commission : 100.45594314561326
# 2021-05-11,  SELL : data_name:I8888 price : 1235.061 , cost : 157109.1676781058 , commission : 138.0572650949963
# 2021-05-11,  SELL : data_name:CF8888 price : 15891.894999999999 , cost : 309026.37957517966 , commission : 19.32381062876311
# 2021-05-11, closed symbol is : BU8888 , total_profit : 298.72625796191875 , net_profit : 168.56231113750582
# 2021-05-11, closed symbol is : RU8888 , total_profit : -22419.936036310177 , net_profit : -22449.89939862641
# 2021-05-11, closed symbol is : Y8888 , total_profit : -13150.366511923787 , net_profit : -13199.816063550777
# 2021-05-11, closed symbol is : JM8888 , total_profit : 114169.18394442077 , net_profit : 113968.27205812954
# 2021-05-11, closed symbol is : I8888 , total_profit : 133312.23689368108 , net_profit : 133036.1223634911
# 2021-05-11, closed symbol is : CF8888 , total_profit : -20272.03001631637 , net_profit : -20310.677637573895
# 2021-05-11, 平多品种:JD8888,平多价格： 4704.06
# 2021-05-11,  SELL : data_name:JD8888 price : 4703.573 , cost : 309919.4744102241 , commission : 64.35205033434886
# 2021-05-11, closed symbol is : JD8888 , total_profit : -72973.93803814442 , net_profit : -73102.64213881311
# 2021-05-11, 平多品种:TA8888,平多价格： 4793.46
# 2021-05-11, 平多品种:PF8888,平多价格： 7217.85
# 2021-05-11,  SELL : data_name:TA8888 price : 4785.007 , cost : 209701.62540233883 , commission : 43.98104559612811
# 2021-05-11,  SELL : data_name:PF8888 price : 7218.8 , cost : 210717.16755712376 , commission : 29.08851015421366
# 2021-05-11, closed symbol is : TA8888 , total_profit : 1979.1470518257652 , net_profit : 1891.184960633509
# 2021-05-11, closed symbol is : PF8888 , total_profit : -15254.59649507273 , net_profit : -15312.773515381157
# 2021-05-11, 做多品种:Y8888,做多价格： 8991.26
# 2021-05-12,  BUY : data_name:Y8888 price : 9033.952 , cost : 260381.56960736646 , commission : 28.960245757687293
# 当天已经执行过了
# 2021-05-12, open symbol is : Y8888 , price : 9033.952
# 2021-05-12, 做多品种:M8888,做多价格： 3740.73
# 2021-05-12, 做多品种:CF8888,做多价格： 16241.94
# 2021-05-12,  BUY : data_name:M8888 price : 3740.1640000000007 , cost : 336006.0474059938 , commission : 89.84118914598764
# 当天已经执行过了
# 2021-05-12,  BUY : data_name:CF8888 price : 16242.077 , cost : 347579.5501913021 , commission : 21.401363844055297
# 当天已经执行过了
# 2021-05-12, open symbol is : M8888 , price : 3740.1640000000007
# 2021-05-12, open symbol is : CF8888 , price : 16242.077
# 2021-05-12, 做多品种:JM8888,做多价格： 2098.32
# 2021-05-12,  BUY : data_name:JM8888 price : 2097.027 , cost : 209103.05262050394 , commission : 99.66780391825736
# 当天已经执行过了
# 2021-05-12, open symbol is : JM8888 , price : 2097.027
# 2021-05-12, 做多品种:BU8888,做多价格： 3143.17
# 2021-05-12, 做多品种:I8888,做多价格： 1302.06
# 2021-05-12,  BUY : data_name:BU8888 price : 3144.676 , cost : 259066.25702251156 , commission : 82.42642603325217
# 当天已经执行过了
# 2021-05-12,  BUY : data_name:I8888 price : 1301.301 , cost : 190914.88528696017 , commission : 146.63201634943178
# 发出信号，正在执行实盘...
# 执行买卖开仓成功.
# 1
# I
# 1
# 当前时间发出做多信号,正在推送TG...
# 2021-05-12, open symbol is : BU8888 , price : 3144.676
# 2021-05-12, open symbol is : I8888 , price : 1301.301
# 2021-05-12, 平多品种:RB8888,平多价格： 5993.75
# 2021-05-12, 结束
# ----------------------------
# End portfolio value 11009442.023950623
# 1.2952284734059556
# ----------------------------
# Total Return:  25.87%
# APR:           0.07%
# Max DrawDown:  8.46%
# 总交易次数 =100,还在交易=17,完成的交易=83.交易成功率百分比=37.35 ,盈亏百分比=1.90
# 连续盈利次数 = 4, 连续亏损次数= 6
# 总盈利次数 = 31 , 总盈利 = 1917400.84 , 平均盈利 =61851.64 ,单次最大盈利 = 256126.18
# 总亏损次数 = 52, 总亏损 = -1696584.31, 平均亏损 =-32626.62,单次最大亏损 = -82969.43
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
